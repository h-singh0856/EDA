# %% [markdown]
# <div style="font-weight: bold; font-size: x-large; color: blue">***Setup***</div>

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import featuretools as ft
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import skew
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from matplotlib.ticker import FuncFormatter
from mpl_toolkits.mplot3d import Axes3D

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
#Returns missing values
def getMissing(df):
    totalRows = df.shape[0]

    temp = pd.DataFrame({
        "Missing": df.isnull().sum(),
        "Missing %": (df.isnull().sum() / totalRows) * 100
        
    })
    
    temp = temp[temp['Missing'] > 0]
    
    return temp.sort_values(by=['Missing'], ascending=False)  

def createHist(df, varName):    
    #Square root rule from ANA600
    numOfBins = round(np.sqrt(len(df)))

    #Histogram
    plt.figure(figsize=(10, 6))  
    plt.hist(df[varName], bins=numOfBins, color="red", alpha=0.7, edgecolor="black", density=True)
    sns.kdeplot(df[varName], color="green", label="Density")    

    #Add comma separator to X-axis
    plt.gca().xaxis.set_major_formatter(FuncFormatter(lambda x, _: f"{x:,.0f}"))

    #Titles and labels
    plt.title("Histogram of '" + varName + "'")
    plt.xlabel(varName)
    plt.ylabel("Frequency")
    plt.grid(True) 
    plt.legend()  # Add legend for the KDE plot
    plt.savefig(f"Graphs/Histogram - {varName}.png", dpi=300, bbox_inches='tight')
    plt.show()

def createScatterPlot(df, varX, varY):
    #Scatter plot
    plt.figure(figsize=(10, 6)) 
    sns.scatterplot(x=df[varX], y=df[varY], color="blue", alpha=0.7, edgecolor="black")

    #Add comma separator to X & Y axis
    plt.gca().xaxis.set_major_formatter(FuncFormatter(lambda x, _: f"{x:,.0f}"))
    plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f"{x:,.0f}"))

    #Titles and labels
    plt.title(f"Scatter Plot of '{varX}' vs '{varY}'")
    plt.xlabel(varX)
    plt.ylabel(varY)
    plt.grid(True)
    plt.savefig(f"Graphs/Scatter plot - {varY} vs {varX}.png", dpi=300, bbox_inches='tight')
    plt.show()
    
def createBoxPlot(df, catVar, numVar):
    #Box plot
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[catVar], y=df[numVar], palette="coolwarm", width=0.6, fliersize=5, linewidth=1.5)

    # Add comma separator to Y-axis
    plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f"{x:,.0f}"))

    # Titles and labels
    plt.title(f"Box Plot of '{numVar}' by '{catVar}'")
    plt.xlabel(catVar)
    plt.ylabel(numVar)
    plt.savefig(f"Graphs/Box plot - {numVar} vs {catVar}.png", dpi=300, bbox_inches='tight')
    plt.show()

def create3DScatterPlot(df, varX, varY, varZ):
    #3D graph
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection='3d')

    #Scatter plot for 3D visualization
    sc = ax.scatter(df[varX], df[varY], df[varZ], c=df[varZ], cmap="coolwarm", alpha=0.7, s=50)

     # Add comma separator to X, Y, and Z axis
    ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: f"{x:,.0f}"))
    ax.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f"{x:,.0f}"))
    ax.zaxis.set_major_formatter(FuncFormatter(lambda x, _: f"{x:,.0f}"))
    
    # Color bar
    plt.colorbar(sc, ax=ax, shrink=0.5, aspect=10, label=varZ)
    
    #Titles and labels
    ax.set_title(f"3D Interaction of {varX}, {varZ}, and {varY}")
    ax.set_xlabel(varX)
    ax.set_ylabel(varY)
    ax.set_zlabel(varZ, labelpad=10)
    plt.savefig(f"Graphs/3D plot - {varX}, {varZ}, and {varY}.png", dpi=300, bbox_inches='tight')
    plt.show()

# %% [markdown]
# <div style="font-weight: bold; font-size: x-large; color: blue">***1. Load Data***</div>

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">1a. Load data & filter rows:</div>

# %%
#Load
housing_df = pd.read_feather("Datasets/Merged.feather")

#Filter rows
housing_df = housing_df[
    (housing_df['City Name'] == 'Bakersfield') &
    #Investors prefer newer properties for lower maintenance and modern code compliance.
    (housing_df['Year Built'] >= 2000)
]

#Print
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5638 entries, 6 to 14539
# Data columns (total 97 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ML Number                            5638 non-null   int64
#  1   List Price                           5638 non-null   float64
#  2   Sold Price                           5638 non-null   float64
#  3   List Date                            5638 non-null   datetime64[ns]
#  4   Sold Date                            5638 non-null   datetime64[ns]
#  5   DOM                                  5638 non-null   float64
#  6   City Name                            5638 non-null   category
#  7   Zipcode                              5638 non-null   category
#  8   Area                                 5638 non-null   category
#  9   Bedrooms                             5638 non-null   float64
#  10  Bathrooms                            5638 non-null   float64
#  11  Sq Foot                              4762 non-null   float64
#  12  Lot Size                             5605 non-null   float64
#  13  Elementry School                     5638 non-null   object
#  14  Junior High School                   5638 non-null   object
#  15  High School                          5638 non-null   object
#  16  Cross Street                         5636 non-null   object
#  17  Latitude                             5638 non-null   float64
#  18  Longitude                            5638 non-null   float64
#  19  Street Name                          5638 non-null   object
#  20  Street Number 1                      5633 non-null   object
#  21  Original Price                       5638 non-null   float64
#  22  Year Built                           5638 non-null   float64
#  23  Pool_None                            5638 non-null   category
#  24  Pool_Inground                        5638 non-null   category
#  25  Pool_Community                       5638 non-null   category
#  26  Pool_Spa                             5638 non-null   category
#  27  Pool_Above_Ground                    5638 non-null   category
#  28  Heating_Central_AC                   5638 non-null   category
#  29  Heating_Central_Heat                 5638 non-null   category
#  30  Heating_Other                        5638 non-null   category
#  31  Heating_Evaporative                  5638 non-null   category
#  32  Heating_Floor/Wall_Heater            5638 non-null   category
#  33  Heating_Wood_Burning_Stove           5638 non-null   category
#  34  Heating_Gas                          5638 non-null   category
#  35  Heating_Electric                     5638 non-null   category
#  36  Heating_Propane                      5638 non-null   category
#  37  Interior_Great_Room                  5638 non-null   category
#  38  Interior_Formal_Dining               5638 non-null   category
#  39  Interior_Breakfast_Area              5638 non-null   category
#  40  Interior_Indoor_Utility              5638 non-null   category
#  41  Interior_Split_Wing                  5638 non-null   category
#  42  Interior_Formal_Living               5638 non-null   category
#  43  Interior_Bonus_Room                  5638 non-null   category
#  44  Interior_Office                      5638 non-null   category
#  45  Interior_Sep._Family_Room            5638 non-null   category
#  46  Interior_Extended_Living             5638 non-null   category
#  47  Interior_Handicap                    5638 non-null   category
#  48  Interior_Basement                    5638 non-null   category
#  49  Exterior_Brick                       5638 non-null   category
#  50  Exterior_Stucco                      5638 non-null   category
#  51  Exterior_Wood                        5638 non-null   category
#  52  Exterior_Other                       5638 non-null   category
#  53  Exterior_Steel_/_Metal               5638 non-null   category
#  54  Exterior_Brick_Veneer                5638 non-null   category
#  55  Exterior_Wood_Frame                  5638 non-null   category
#  56  Other Features_Horse                 5638 non-null   category
#  57  Other Features_Alley                 5638 non-null   category
#  58  Other Features_Cul_De_Sac            5638 non-null   category
#  59  Other Features_Corner                5638 non-null   category
#  60  Other Features_Gated_Community       5638 non-null   category
#  61  Other Features_Adult_Community       5638 non-null   category
#  62  Other Features_Mountain              5638 non-null   category
#  63  Other Features_River                 5638 non-null   category
#  64  Other Features_Lake                  5638 non-null   category
#  65  Other Features_Golf_Course           5638 non-null   category
#  66  Other Features_Truck_Door            5638 non-null   category
#  67  Other Features_Partial_Fenced        5638 non-null   category
#  68  Other Features_Overhead_Door         5638 non-null   category
#  69  Other Features_Additional_Buildings  5638 non-null   category
#  70  Other Features_Wet_Sprinklers        5638 non-null   category
#  71  Other Features_Security_Fence        5638 non-null   category
#  72  Other Features_Burglar_Alarm         5638 non-null   category
#  73  Other Features_Smoke/Fire_Alarm      5638 non-null   category
#  74  Other Features_Security_Lighting     5638 non-null   category
#  75  Other Features_Sign                  5638 non-null   category
#  76  Other Features_Display_Window        5638 non-null   category
#  77  Other Features_Laundry_Hookup        5638 non-null   category
#  78  Other Features_Outside_Storage       5638 non-null   category
#  79  Other Features_ADA_Compliant         5638 non-null   category
#  80  Avg Monthly Mortgage Rate (30Y)      5638 non-null   float64
#  81  Avg Monthly Mortgage Rate (15Y)      5638 non-null   float64
#  82  Walk Score                           5638 non-null   float64
#  83  Transit Score                        4940 non-null   float64
#  84  Bike Score                           5557 non-null   float64
#  85  Elementary School Ratings            5594 non-null   float64
#  86  Junior High School Ratings           5355 non-null   float64
#  87  High School Ratings                  5595 non-null   float64
#  88  Sex Offender Count                   5638 non-null   float64
#  89  Mall Name                            5638 non-null   object
#  90  Mall Vicinity                        5638 non-null   object
#  91  Mall Distance (Meters)               5638 non-null   float64
#  92  Mall Duration (Secs)                 5638 non-null   float64
#  93  Mall Ratings Total                   5638 non-null   float64
#  94  Mall Ratings                         5638 non-null   float64
#  95  Downtown Distance (Meters)           5638 non-null   float64
#  96  Downtown Duration (Secs)             5638 non-null   float64
# dtypes: category(60), datetime64[ns](2), float64(26), int64(1), object(8)
# memory usage: 2.0+ MB

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">1b. Save the original dataset (For clustering).</div>

# %%
#Original (For clustering)
housing_df.to_feather("Datasets/V2/Clustering/Merged V2.feather")

# %% [markdown]
# <div style="font-weight: bold; font-size: x-large; color: blue">***2. Missing Values***</div>

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">2a. Identify columns with missing values.</div>

# %%
#Print missing values
getMissing(housing_df)
# Out:
#                             Missing  Missing %
# Sq Foot                         876      15.54
# Transit Score                   698      12.38
# Junior High School Ratings      283       5.02
# Bike Score                       81       1.44
# Elementary School Ratings        44       0.78
# High School Ratings              43       0.76
# Lot Size                         33       0.59
# Street Number 1                   5       0.09
# Cross Street                      2       0.04

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">2b. Impute missing values.</div>

# %% [markdown]
# <div style="font-size: medium; color: green"><span style="font-weight: bold">Observations:</span> I conducted comparative analyses after imputing missing values, assessing means, medians, and correlations between the original and imputed data. The correlation between Transit Score and the outcome variable Sold Price decreased by 5.88%, while the means, medians, and correlations for the other imputed columns remained largely unchanged.</div>

# %%
#Vars
stats = pd.DataFrame(index=[
    #Mean
    'Mean (Original)',
    'Mean (Imputed)',
    'Percentage Difference (Mean)',

    #Median
    'Median (Original)',
    'Median (Imputed)',
    'Percentage Difference (Median)',

    #Correlation
    'Correlation (Original)',
    'Correlation (Imputed)',
    'Percentage Difference (Correlation)',
])

cols = [
    #Unique key
    'ML Number',
    
    #Add Sold Price to compute correlation
    'Sold Price',

    #Columns to impute
    'Sq Foot',
    'Transit Score',
    'Junior High School Ratings',
    'Bike Score',
    'Elementary School Ratings',
    'High School Ratings',
    'Lot Size'
]

#Impute
#I tried different numbers and 45 gave me the best results
imputer = KNNImputer(n_neighbors=45)

imputed_df = pd.DataFrame(imputer.fit_transform(housing_df[cols]), columns=housing_df[cols].columns)

#Compute statistics
for col in cols:
    #Mean
    mean_original = round(housing_df[col].mean(), 2)
    mean_imputed = round(imputed_df[col].mean(), 2)

    #Median
    median_original = round(housing_df[col].median(), 2)
    median_imputed = round(imputed_df[col].median(), 2)

    #Correlation
    corr_original = round(housing_df[col].corr(housing_df['Sold Price']), 2)
    corr_imputed = round(imputed_df[col].corr(imputed_df['Sold Price']), 2)

    stats[col] = [
         #Mean
        mean_original, 
        mean_imputed, 
        ((mean_imputed - mean_original) / mean_original * 100), 

        #Median
        median_original, 
        median_imputed,  
        ((median_imputed - median_original) / median_original * 100), 

        #Correlation
        corr_original, 
        corr_imputed,  
        ((corr_imputed - corr_original) / corr_original * 100), 
    ]

#Update the original dataset
housing_df = housing_df.set_index("ML Number")

#Overwrite=False ensures that only missing values are replaced, preserving the original values where they were not missing.
housing_df.update(imputed_df.set_index("ML Number"), overwrite=False)

#Print stats
stats.T
# Out:
#                             Mean (Original)  Mean (Imputed)  \
# ML Number                      202008926.40    202008926.40
# Sold Price                        435971.73       435971.73
# Sq Foot                             2121.87         2114.04
# Transit Score                         14.21           14.17
# Junior High School Ratings             4.14            4.14
# Bike Score                            33.68           33.68
# Elementary School Ratings              5.03            5.03
# High School Ratings                    5.74            5.74
# Lot Size                           11733.49        11714.96
#
#                             Percentage Difference (Mean)  Median (Original)  \
# ML Number                                           0.00       202111817.00
# Sold Price                                          0.00          400000.00
# Sq Foot                                            -0.37            1998.00
# Transit Score                                      -0.28              17.00
# Junior High School Ratings                          0.00               4.00
# Bike Score                                          0.00              32.00
# Elementary School Ratings                           0.00               5.00
# High School Ratings                                 0.00               6.00
# Lot Size                                           -0.16            7650.00
#
#                             Median (Imputed)  Percentage Difference (Median)  \
# ML Number                       202111817.00                            0.00
# Sold Price                         400000.00                            0.00
# Sq Foot                              1986.27                           -0.59
# Transit Score                          17.00                            0.00
# Junior High School Ratings              4.00                            0.00
# Bike Score                             32.00                            0.00
# Elementary School Ratings               5.00                            0.00
# High School Ratings                     6.00                            0.00
# Lot Size                             7649.50                           -0.01
#
#                             Correlation (Original)  Correlation (Imputed)  \
# ML Number                                     0.03                   0.03
# Sold Price                                    1.00                   1.00
# Sq Foot                                       0.83                   0.84
# Transit Score                                -0.17                  -0.16
# Junior High School Ratings                   -0.11                  -0.11
# Bike Score                                   -0.02                  -0.02
# Elementary School Ratings                     0.14                   0.14
# High School Ratings                          -0.06                  -0.06
# Lot Size                                      0.18                   0.18
#
#                             Percentage Difference (Correlation)
# ML Number                                                  0.00
# Sold Price                                                 0.00
# Sq Foot                                                    1.20
# Transit Score                                             -5.88
# Junior High School Ratings                                -0.00
# Bike Score                                                -0.00
# Elementary School Ratings                                  0.00
# High School Ratings                                       -0.00
# Lot Size                                                   0.00

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">2c. Check missing values again.</div>

# %%
#Print missing values
getMissing(housing_df)
# Out:
#                  Missing  Missing %
# Street Number 1        5       0.09
# Cross Street           2       0.04

# %% [markdown]
# <div style="font-weight: bold; font-size: x-large; color: blue">***3. Feature Engineering & Column Filtering***</div>

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">3a. Add new features:</div>

# %%
#This will prevent exponential notation in graphs and tables
housing_df['Sold Price (x100,000)'] =  (housing_df['Sold Price'] / 100000).astype('float')

#Age
housing_df['Age'] =  (housing_df['Sold Date'].dt.year - housing_df['Year Built']).astype('float')

#Month of sale
housing_df['SaleMonth'] =  housing_df['Sold Date'].dt.month.astype('float')

#Check
housing_df[[
    'Sold Price',
    'Sold Price (x100,000)',
    'Age',
    'SaleMonth', 
    'Sold Date',
    'Year Built'
]].head()
# Out:
#            Sold Price  Sold Price (x100,000)   Age  SaleMonth  Sold Date  \
# ML Number
# 202310874   412990.00                   4.13  0.00      12.00 2023-12-26
# 202310704   430000.00                   4.30 18.00      11.00 2023-11-28
# 202310767   360000.00                   3.60 17.00      11.00 2023-11-15
# 202310769   315000.00                   3.15 18.00      11.00 2023-11-16
# 202310294   445770.00                   4.46  0.00       9.00 2023-09-26
#
#            Year Built
# ML Number
# 202310874     2023.00
# 202310704     2005.00
# 202310767     2006.00
# 202310769     2005.00
# 202310294     2023.00

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">3b. Filter columns:</div>

# %%
#Home Value = f(
                #Sq Foot,
                #Lot Size,
                #Bedrooms,
                #Bathrooms,
                #Age of the property at the time of sale,
                #Days on Market,
                #Pool Features,
                #Zip Code, 
                #School Ratings,
                #Count of Sex Offenders in Zip Code,
                #Walk Score, 
                #Transit Score,
                #Bike Score,
                #Driving distance to nearest shopping mall,
                #Driving distance to downtown,
                #Monthly Mortgage Rate, 
                #Month of Sale
            #)
housing_filtered_df = housing_df[[    
    #Numerical
    'Sold Price (x100,000)',
    'Sold Price',
    'Sq Foot',     
    'Lot Size',  
    'Bedrooms',                       
    'Bathrooms',  
    'Age', 
    'DOM',
    'Elementary School Ratings',             
    'Junior High School Ratings',               
    'High School Ratings',           
    'Sex Offender Count',
    'Walk Score',
    'Transit Score',               
    'Bike Score',  
    'Mall Distance (Meters)',  
    'Downtown Distance (Meters)',     
    'Avg Monthly Mortgage Rate (30Y)',
    'SaleMonth',
    
    #Categorical   
    #The first 4 pool variables contain boolean values
    'Pool_Inground',                           
    'Pool_Community',                          
    'Pool_Spa',                           
    'Pool_Above_Ground',
    'Zipcode'
]]

#Print shape
housing_filtered_df.shape
# Out:
# (5638, 24)

# %%
#Print records 
housing_filtered_df.head()
# Out:
#            Sold Price (x100,000)  Sold Price  Sq Foot  Lot Size  Bedrooms  \
# ML Number
# 202310874                   4.13   412990.00  1852.27   6215.00      4.00
# 202310704                   4.30   430000.00  2222.00   8276.00      4.00
# 202310767                   3.60   360000.00  1445.00   6534.00      3.00
# 202310769                   3.15   315000.00  1080.00   5227.00      3.00
# 202310294                   4.46   445770.00  2081.96   6534.00      4.00
#
#            Bathrooms   Age   DOM  Elementary School Ratings  \
# ML Number
# 202310874       3.00  0.00 10.00                       8.00
# 202310704       2.00 18.00 12.00                       6.00
# 202310767       2.00 17.00 29.00                       9.00
# 202310769       2.00 18.00 16.00                       5.00
# 202310294       3.00  0.00  0.00                       5.00
#
#            Junior High School Ratings  High School Ratings  \
# ML Number
# 202310874                        3.00                 4.00
# 202310704                        6.00                 8.00
# 202310767                        6.00                 7.00
# 202310769                        3.00                 5.00
# 202310294                        4.29                 6.00
#
#            Sex Offender Count  Walk Score  Transit Score  Bike Score  \
# ML Number
# 202310874               59.00        8.00          22.00       32.00
# 202310704              139.00        8.00           0.00       30.00
# 202310767               34.00       13.00          17.00       36.00
# 202310769              139.00       36.00          33.00       45.00
# 202310294               43.00        2.00           0.00       30.00
#
#            Mall Distance (Meters)  Downtown Distance (Meters)  \
# ML Number
# 202310874                 2660.00                    18091.00
# 202310704                 3914.00                     5902.00
# 202310767                 2452.00                    13777.00
# 202310769                 1655.00                     8080.00
# 202310294                 4565.00                    21782.00
#
#            Avg Monthly Mortgage Rate (30Y)  SaleMonth Pool_Inground  \
# ML Number
# 202310874                             6.82      12.00             0
# 202310704                             7.44      11.00             1
# 202310767                             7.44      11.00             0
# 202310769                             7.44      11.00             0
# 202310294                             7.20       9.00             0
#
#           Pool_Community Pool_Spa Pool_Above_Ground Zipcode
# ML Number
# 202310874              0        0                 0   93313
# 202310704              0        0                 0   93308
# 202310767              0        0                 0   93312
# 202310769              0        0                 0   93308
# 202310294              0        0                 0   93311

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">3c. Save the original data to generate the winsorized version.</div>

# %%
#Save
housing_filtered_df.to_feather("Datasets/V2/Prediction/Merged V2 - 100% (Original - For generating winsorized version).feather")

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">3d. Identify numerical and categorical columns:</div>

# %%
#Vars
numerical_cols = []
categorical_cols = []

#Iterate and add
for c in housing_filtered_df.columns:  
    #Vars
    dtype = housing_filtered_df[c].dtype

    #Check
    if (dtype == 'float64' or dtype == 'int64'):
        numerical_cols.append(c)

    elif (dtype == 'category'):
        categorical_cols.append(c)

#Print numerical
numerical_cols
# Out:
# ['Sold Price (x100,000)',
#  'Sold Price',
#  'Sq Foot',
#  'Lot Size',
#  'Bedrooms',
#  'Bathrooms',
#  'Age',
#  'DOM',
#  'Elementary School Ratings',
#  'Junior High School Ratings',
#  'High School Ratings',
#  'Sex Offender Count',
#  'Walk Score',
#  'Transit Score',
#  'Bike Score',
#  'Mall Distance (Meters)',
#  'Downtown Distance (Meters)',
#  'Avg Monthly Mortgage Rate (30Y)',
#  'SaleMonth']

# %%
#Print categorical
categorical_cols
# Out:
# ['Pool_Inground', 'Pool_Community', 'Pool_Spa', 'Pool_Above_Ground', 'Zipcode']

# %% [markdown]
# <div style="font-weight: bold; font-size: x-large; color: blue">***4. Correlation Analysis and Data Summary***</div>

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">4a. Compute the correlation matrix.</div>

# %% [markdown]
# <div style="font-size: medium; color: green"><span style="font-weight: bold">Observations:</span> The following variables have a correlation of less than 0.10 with the outcome variable: Age, DOM, High School Ratings, Bike Score, Mall Distance (Meters), and SaleMonth. The Bathrooms variable has a high correlation with Sq Foot.</div>

# %%
#Vars
temp = numerical_cols.copy()
temp.remove('Sold Price (x100,000)')

#Print
housing_filtered_df[temp].corr(method = 'pearson')
# Out:
#                                  Sold Price  Sq Foot  Lot Size  Bedrooms  \
# Sold Price                             1.00     0.84      0.18      0.39
# Sq Foot                                0.84     1.00      0.13      0.50
# Lot Size                               0.18     0.13      1.00      0.01
# Bedrooms                               0.39     0.50      0.01      1.00
# Bathrooms                              0.66     0.75      0.07      0.55
# Age                                    0.01    -0.03      0.00     -0.13
# DOM                                    0.07     0.12      0.01      0.04
# Elementary School Ratings              0.14     0.18      0.01      0.01
# Junior High School Ratings            -0.11    -0.09      0.00     -0.08
# High School Ratings                   -0.06    -0.03     -0.01     -0.00
# Sex Offender Count                    -0.33    -0.36      0.03     -0.17
# Walk Score                            -0.17    -0.20     -0.04     -0.07
# Transit Score                         -0.16    -0.21     -0.01     -0.06
# Bike Score                            -0.02    -0.04     -0.06     -0.04
# Mall Distance (Meters)                 0.04     0.05      0.27     -0.06
# Downtown Distance (Meters)             0.13     0.14      0.08      0.13
# Avg Monthly Mortgage Rate (30Y)        0.24     0.00      0.01      0.02
# SaleMonth                              0.00     0.00     -0.02      0.00
#
#                                  Bathrooms   Age   DOM  \
# Sold Price                            0.66  0.01  0.07
# Sq Foot                               0.75 -0.03  0.12
# Lot Size                              0.07  0.00  0.01
# Bedrooms                              0.55 -0.13  0.04
# Bathrooms                             1.00 -0.13  0.08
# Age                                  -0.13  1.00 -0.04
# DOM                                   0.08 -0.04  1.00
# Elementary School Ratings             0.12  0.10  0.03
# Junior High School Ratings           -0.07  0.04 -0.01
# High School Ratings                  -0.04  0.14 -0.02
# Sex Offender Count                   -0.21 -0.06 -0.01
# Walk Score                           -0.16  0.35 -0.04
# Transit Score                        -0.13  0.17 -0.06
# Bike Score                           -0.07  0.28 -0.01
# Mall Distance (Meters)                0.05 -0.21  0.03
# Downtown Distance (Meters)            0.13 -0.28  0.02
# Avg Monthly Mortgage Rate (30Y)       0.05  0.05  0.14
# SaleMonth                             0.00 -0.02  0.06
#
#                                  Elementary School Ratings  \
# Sold Price                                            0.14
# Sq Foot                                               0.18
# Lot Size                                              0.01
# Bedrooms                                              0.01
# Bathrooms                                             0.12
# Age                                                   0.10
# DOM                                                   0.03
# Elementary School Ratings                             1.00
# Junior High School Ratings                           -0.04
# High School Ratings                                  -0.04
# Sex Offender Count                                   -0.22
# Walk Score                                           -0.02
# Transit Score                                        -0.21
# Bike Score                                            0.13
# Mall Distance (Meters)                               -0.02
# Downtown Distance (Meters)                            0.08
# Avg Monthly Mortgage Rate (30Y)                       0.03
# SaleMonth                                             0.00
#
#                                  Junior High School Ratings  \
# Sold Price                                            -0.11
# Sq Foot                                               -0.09
# Lot Size                                               0.00
# Bedrooms                                              -0.08
# Bathrooms                                             -0.07
# Age                                                    0.04
# DOM                                                   -0.01
# Elementary School Ratings                             -0.04
# Junior High School Ratings                             1.00
# High School Ratings                                    0.49
# Sex Offender Count                                     0.28
# Walk Score                                            -0.02
# Transit Score                                          0.05
# Bike Score                                            -0.18
# Mall Distance (Meters)                                 0.26
# Downtown Distance (Meters)                            -0.16
# Avg Monthly Mortgage Rate (30Y)                       -0.01
# SaleMonth                                              0.01
#
#                                  High School Ratings  Sex Offender Count  \
# Sold Price                                     -0.06               -0.33
# Sq Foot                                        -0.03               -0.36
# Lot Size                                       -0.01                0.03
# Bedrooms                                       -0.00               -0.17
# Bathrooms                                      -0.04               -0.21
# Age                                             0.14               -0.06
# DOM                                            -0.02               -0.01
# Elementary School Ratings                      -0.04               -0.22
# Junior High School Ratings                      0.49                0.28
# High School Ratings                             1.00               -0.06
# Sex Offender Count                             -0.06                1.00
# Walk Score                                      0.07                0.06
# Transit Score                                  -0.15                0.36
# Bike Score                                     -0.09               -0.18
# Mall Distance (Meters)                          0.07                0.32
# Downtown Distance (Meters)                     -0.15               -0.22
# Avg Monthly Mortgage Rate (30Y)                 0.01                0.01
# SaleMonth                                      -0.01               -0.03
#
#                                  Walk Score  Transit Score  Bike Score  \
# Sold Price                            -0.17          -0.16       -0.02
# Sq Foot                               -0.20          -0.21       -0.04
# Lot Size                              -0.04          -0.01       -0.06
# Bedrooms                              -0.07          -0.06       -0.04
# Bathrooms                             -0.16          -0.13       -0.07
# Age                                    0.35           0.17        0.28
# DOM                                   -0.04          -0.06       -0.01
# Elementary School Ratings             -0.02          -0.21        0.13
# Junior High School Ratings            -0.02           0.05       -0.18
# High School Ratings                    0.07          -0.15       -0.09
# Sex Offender Count                     0.06           0.36       -0.18
# Walk Score                             1.00           0.48        0.57
# Transit Score                          0.48           1.00        0.19
# Bike Score                             0.57           0.19        1.00
# Mall Distance (Meters)                -0.47          -0.22       -0.52
# Downtown Distance (Meters)            -0.38          -0.28       -0.31
# Avg Monthly Mortgage Rate (30Y)       -0.02          -0.05        0.00
# SaleMonth                             -0.00          -0.01        0.01
#
#                                  Mall Distance (Meters)  \
# Sold Price                                         0.04
# Sq Foot                                            0.05
# Lot Size                                           0.27
# Bedrooms                                          -0.06
# Bathrooms                                          0.05
# Age                                               -0.21
# DOM                                                0.03
# Elementary School Ratings                         -0.02
# Junior High School Ratings                         0.26
# High School Ratings                                0.07
# Sex Offender Count                                 0.32
# Walk Score                                        -0.47
# Transit Score                                     -0.22
# Bike Score                                        -0.52
# Mall Distance (Meters)                             1.00
# Downtown Distance (Meters)                         0.30
# Avg Monthly Mortgage Rate (30Y)                    0.03
# SaleMonth                                         -0.02
#
#                                  Downtown Distance (Meters)  \
# Sold Price                                             0.13
# Sq Foot                                                0.14
# Lot Size                                               0.08
# Bedrooms                                               0.13
# Bathrooms                                              0.13
# Age                                                   -0.28
# DOM                                                    0.02
# Elementary School Ratings                              0.08
# Junior High School Ratings                            -0.16
# High School Ratings                                   -0.15
# Sex Offender Count                                    -0.22
# Walk Score                                            -0.38
# Transit Score                                         -0.28
# Bike Score                                            -0.31
# Mall Distance (Meters)                                 0.30
# Downtown Distance (Meters)                             1.00
# Avg Monthly Mortgage Rate (30Y)                        0.05
# SaleMonth                                              0.01
#
#                                  Avg Monthly Mortgage Rate (30Y)  SaleMonth
# Sold Price                                                  0.24       0.00
# Sq Foot                                                     0.00       0.00
# Lot Size                                                    0.01      -0.02
# Bedrooms                                                    0.02       0.00
# Bathrooms                                                   0.05       0.00
# Age                                                         0.05      -0.02
# DOM                                                         0.14       0.06
# Elementary School Ratings                                   0.03       0.00
# Junior High School Ratings                                 -0.01       0.01
# High School Ratings                                         0.01      -0.01
# Sex Offender Count                                          0.01      -0.03
# Walk Score                                                 -0.02      -0.00
# Transit Score                                              -0.05      -0.01
# Bike Score                                                  0.00       0.01
# Mall Distance (Meters)                                      0.03      -0.02
# Downtown Distance (Meters)                                  0.05       0.01
# Avg Monthly Mortgage Rate (30Y)                             1.00       0.00
# SaleMonth                                                   0.00       1.00

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">4b. Drop columns with low correlation to the outcome variable and high multicollinearity.</div>

# %% [markdown]
# <div style="font-size: medium; color: green"><span style="font-weight: bold">Comments:</span> Even though some of the variables I retained have a weak correlation with the outcome variable, they help create useful interactions that may have a stronger correlation with the outcome variable. Additionally, the Recursive Feature Elimination (RFE) technique will remove them if they are not found to be useful.</div>

# %%
#Following variables have a correlation of less than 0.10 with the outcome variable
numerical_cols.remove('Age')
numerical_cols.remove('DOM')
numerical_cols.remove('High School Ratings')
numerical_cols.remove('Bike Score')
numerical_cols.remove('Mall Distance (Meters)')
numerical_cols.remove('SaleMonth')

#Following variable has a high correlation with Sq Foot
numerical_cols.remove('Bathrooms')

#Drop columns
housing_filtered_df.drop(columns=[
    'Age',
    'DOM',
    'High School Ratings',
    'Bike Score',
    'Mall Distance (Meters)',
    'SaleMonth',
    'Bathrooms'
], inplace=True)

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">4c. Generate descriptive stats.</div>

# %% [markdown]
# <div style="font-size: medium; color: green"><span style="font-weight: bold">Observations:</span> Some columns have outliers, and I verified a few random values on Zillow, confirming they are not data entry errors.</div>

# %%
#Vars
percentiles = np.concatenate((np.array([0.01, 0.02, 0.03, 0.04, 0.96, 0.97, 0.98, 0.99]), np.arange(0.05, 1.0, 0.05)))

temp = numerical_cols.copy()
temp.remove('Sold Price')

#Print
housing_filtered_df[temp].describe(percentiles = percentiles)
# Out:
#        Sold Price (x100,000)  Sq Foot   Lot Size  Bedrooms  \
# count                5638.00  5638.00    5638.00   5638.00
# mean                    4.36  2114.04   11714.96      3.66
# std                     1.82   677.08   73887.49      0.76
# min                     1.25   816.00       0.14      0.00
# 1%                      2.23  1116.00    2178.00      2.00
# 2%                      2.40  1174.00    3920.00      2.00
# 3%                      2.46  1247.11    4500.00      2.00
# 4%                      2.55  1273.00    4791.00      2.00
# 5%                      2.60  1314.70    4792.00      3.00
# 10%                     2.87  1433.70    6010.10      3.00
# 15%                     3.00  1511.00    6098.00      3.00
# 20%                     3.15  1600.00    6098.00      3.00
# 25%                     3.30  1662.00    6534.00      3.00
# 30%                     3.45  1721.52    6534.00      3.00
# 35%                     3.60  1808.00    6969.00      3.00
# 40%                     3.70  1858.93    7200.00      3.00
# 45%                     3.85  1918.00    7405.00      4.00
# 50%                     4.00  1986.27    7649.50      4.00
# 55%                     4.14  2054.00    7841.00      4.00
# 60%                     4.25  2148.20    8276.00      4.00
# 65%                     4.40  2247.05    8712.00      4.00
# 70%                     4.60  2346.88    9583.00      4.00
# 75%                     4.85  2467.75   10019.00      4.00
# 80%                     5.15  2567.64   10890.00      4.00
# 85%                     5.55  2695.00   11425.60      4.00
# 90%                     6.13  2870.30   13503.00      5.00
# 95%                     7.25  3239.00   17859.00      5.00
# 96%                     7.70  3324.00   20263.72      5.00
# 97%                     8.39  3463.58   22215.00      5.00
# 98%                     9.50  3674.11   27007.00      5.00
# 99%                    11.36  4346.00   43560.00      5.00
# max                    31.90 11014.00 4758494.00      7.00
#
#        Elementary School Ratings  Junior High School Ratings  \
# count                    5638.00                     5638.00
# mean                        5.03                        4.14
# std                         1.69                        1.53
# min                         2.00                        2.00
# 1%                          2.00                        2.00
# 2%                          2.00                        2.00
# 3%                          2.00                        2.00
# 4%                          2.00                        2.00
# 5%                          3.00                        2.00
# 10%                         3.00                        2.00
# 15%                         3.00                        2.00
# 20%                         4.00                        3.00
# 25%                         4.00                        3.00
# 30%                         4.00                        3.00
# 35%                         4.00                        3.00
# 40%                         4.00                        4.00
# 45%                         5.00                        4.00
# 50%                         5.00                        4.00
# 55%                         5.00                        4.00
# 60%                         5.00                        4.00
# 65%                         6.00                        4.00
# 70%                         6.00                        5.00
# 75%                         6.00                        6.00
# 80%                         7.00                        6.00
# 85%                         7.00                        6.00
# 90%                         7.00                        6.00
# 95%                         8.00                        7.00
# 96%                         8.00                        7.00
# 97%                         8.00                        7.00
# 98%                         8.00                        7.00
# 99%                         9.00                        7.00
# max                         9.00                        7.00
#
#        Sex Offender Count  Walk Score  Transit Score  \
# count             5638.00     5638.00        5638.00
# mean                65.54       15.29          14.17
# std                 49.99       14.02          10.35
# min                  0.00        0.00           0.00
# 1%                  22.00        0.00           0.00
# 2%                  22.00        0.00           0.00
# 3%                  22.00        0.00           0.00
# 4%                  22.00        0.00           0.00
# 5%                  22.00        0.00           0.00
# 10%                 22.00        1.00           0.00
# 15%                 22.00        3.00           0.00
# 20%                 34.00        4.00           0.00
# 25%                 34.00        5.00           0.00
# 30%                 34.00        6.00           9.72
# 35%                 34.00        7.00          12.00
# 40%                 43.00        8.00          13.60
# 45%                 43.00        9.00          15.00
# 50%                 43.00       11.00          17.00
# 55%                 43.00       12.00          17.00
# 60%                 59.00       14.00          18.00
# 65%                 59.00       16.00          20.00
# 70%                 59.00       18.00          21.00
# 75%                 79.00       22.00          21.97
# 80%                110.00       26.00          22.55
# 85%                115.85       31.00          24.00
# 90%                139.00       36.00          26.00
# 95%                190.00       45.00          31.00
# 96%                190.00       47.00          32.00
# 97%                190.00       50.00          32.00
# 98%                190.00       53.00          33.00
# 99%                190.00       59.00          33.00
# max                190.00       80.00          44.00
#
#        Downtown Distance (Meters)  Avg Monthly Mortgage Rate (30Y)
# count                     5638.00                          5638.00
# mean                     15198.23                             4.54
# std                       4732.62                             1.74
# min                       1942.00                             2.68
# 1%                        6232.92                             2.68
# 2%                        7491.74                             2.68
# 3%                        7841.00                             2.68
# 4%                        8072.00                             2.77
# 5%                        8339.35                             2.77
# 10%                      10423.70                             2.84
# 15%                      11535.20                             2.89
# 20%                      12718.80                             2.94
# 25%                      13464.25                             3.02
# 30%                      13961.60                             3.06
# 35%                      14472.95                             3.07
# 40%                      14841.20                             3.10
# 45%                      15229.00                             3.23
# 50%                      15601.00                             3.45
# 55%                      15888.00                             4.17
# 60%                      16230.40                             4.98
# 65%                      16581.00                             5.52
# 70%                      17087.90                             6.34
# 75%                      17418.25                             6.50
# 80%                      17870.40                             6.80
# 85%                      18300.45                             6.84
# 90%                      18700.00                             6.90
# 95%                      19744.95                             7.07
# 96%                      20067.56                             7.07
# 97%                      20448.89                             7.44
# 98%                      20724.12                             7.44
# 99%                      21485.67                             7.62
# max                     186638.00                             7.62

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">4d. Compute absolute skewness.</div>

# %% [markdown]
# <div style="font-size: medium; color: green"><span style="font-weight: bold">Observations:</span> 'Lot Size' and 'Downtown Distance (Meters)' variables have an absolute skewness greater than 5.</div>

# %%
#Vars
temp = numerical_cols.copy()
temp.remove('Sold Price (x100,000)')

#Print
housing_filtered_df[temp].apply(lambda x: abs(skew(x, nan_policy = 'raise'))).sort_values(ascending = False)
# Out:
# Lot Size                          51.28
# Downtown Distance (Meters)        16.79
# Sold Price                         4.03
# Sq Foot                            2.59
# Sex Offender Count                 1.40
# Walk Score                         1.29
# Avg Monthly Mortgage Rate (30Y)    0.41
# Junior High School Ratings         0.37
# Elementary School Ratings          0.29
# Bedrooms                           0.19
# Transit Score                      0.11
# dtype: float64

# %% [markdown]
# <div style="font-weight: bold; font-size: x-large; color: blue">***5. Combine Sparse Categories***</div>

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">5a. Display the count of records in each category.</div>

# %%
#Filtering records after creating categorical columns retains unused categories, which may appear with a count of 0 in value_counts(). Following code will fix it.
housing_filtered_df["Zipcode"] = housing_filtered_df["Zipcode"].astype(str).astype("category")

housing_filtered_df["Pool_Inground"] = housing_filtered_df["Pool_Inground"].astype(str).astype("category")
housing_filtered_df["Pool_Community"] = housing_filtered_df["Pool_Community"].astype(str).astype("category")
housing_filtered_df["Pool_Spa"] = housing_filtered_df["Pool_Spa"].astype(str).astype("category")
housing_filtered_df["Pool_Above_Ground"] = housing_filtered_df["Pool_Above_Ground"].astype(str).astype("category")

#Print
for c in categorical_cols: 
    print(housing_filtered_df[c].value_counts())
    print('\n')
# Out:
# Pool_Inground
# 0    4289
# 1    1349
# Name: count, dtype: int64
#
#
# Pool_Community
# 0    5066
# 1     572
# Name: count, dtype: int64
#
#
# Pool_Spa
# 0    5251
# 1     387
# Name: count, dtype: int64
#
#
# Pool_Above_Ground
# 0    5603
# 1      35
# Name: count, dtype: int64
#
#
# Zipcode
# 93312    1206
# 93311    1188
# 93314     928
# 93313     903
# 93306     549
# 93307     481
# 93308     350
# 93304      12
# 93301      11
# 93309       6
# 93305       3
# 93303       1
# Name: count, dtype: int64

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">5b. Combine sparse ZIP codes.</div>

# %%
#Merge the following zip codes due to sparsity and geographic proximity. 
temp = ["93304", "93301", "93309", "93305"]

#Categorize the above listed zip codes as 'Other'
housing_filtered_df["Zipcode"] = housing_filtered_df["Zipcode"].replace(temp, "Other")

#Remove ZIP code 93303 as it’s outside the town with only one house.
housing_filtered_df = housing_filtered_df[housing_filtered_df["Zipcode"] != "93303"]

#Filtering records after creating categorical columns retains unused categories, which may appear with a count of 0 in value_counts(). Following code will fix it.
housing_filtered_df["Zipcode"] = housing_filtered_df["Zipcode"].astype(str).astype("category")

#Print
housing_filtered_df['Zipcode'].value_counts()
# Out:
# Zipcode
# 93312    1206
# 93311    1188
# 93314     928
# 93313     903
# 93306     549
# 93307     481
# 93308     350
# Other      32
# Name: count, dtype: int64

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">5c. Remove specific pool features.</div>

# %%
#Remove Pool_Above_Ground because it has very low counts of 1,
#which might not contribute much to the model and could even lead to instability in estimates due to class imbalance.
housing_filtered_df = housing_filtered_df.drop(columns=['Pool_Above_Ground'])

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">5d. Detect redundant categories by examining the target variable's mean.</div>

# %% [markdown]
# <mark style="font-size: medium;">This method is less reliable because the categorical variables involved have class imbalance, which can distort the mean or median, reducing its effectiveness in identifying redundant categories.</mark>

# %% [markdown]
# <div style="font-size: medium; color: green"><span style="font-weight: bold">Observations:</span> I didn't find any redundant categories.</div>

# %%
#Vars
temp = housing_filtered_df[["Sold Price", "Zipcode", "Pool_Inground", "Pool_Community", "Pool_Spa"]].dropna()

#Print
temp.groupby("Zipcode")["Sold Price"].mean().sort_values()
# Out:
# Zipcode
# Other   312699.69
# 93307   313413.55
# 93306   370580.23
# 93308   373652.32
# 93313   375484.21
# 93312   443348.04
# 93311   483312.86
# 93314   554830.56
# Name: Sold Price, dtype: float64

# %%
#Print
temp.groupby("Pool_Inground")["Sold Price"].mean().sort_values()
# Out:
# Pool_Inground
# 0   392657.29
# 1   573809.60
# Name: Sold Price, dtype: float64

# %%
#Print
temp.groupby("Pool_Community")["Sold Price"].mean().sort_values()
# Out:
# Pool_Community
# 1   418732.77
# 0   437960.21
# Name: Sold Price, dtype: float64

# %%
#Print
temp.groupby("Pool_Spa")["Sold Price"].mean().sort_values()
# Out:
# Pool_Spa
# 0   421689.30
# 1   630270.67
# Name: Sold Price, dtype: float64

# %% [markdown]
# <div style="font-weight: bold; font-size: x-large; color: blue">***6. Interaction Terms***</div>

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">6a. Create two-way interaction terms between numerical variables.</div>

# %%
#Create entity set
es = ft.EntitySet(id = 'housing_data')

#Skip logical_types parameter as all variables involved are numerical
es = es.add_dataframe(
    dataframe_name="Housing Data",
    dataframe=housing_filtered_df[numerical_cols],
    index=housing_filtered_df.index.name
)

#Run deep feature synthesis
feature_matrix, feature_defs = ft.dfs(
    entityset = es,
    target_dataframe_name = 'Housing Data',
    trans_primitives = ['multiply_numeric'],
    ignore_columns   = {
        'Housing Data': ['Sold Price (x100,000)']
    },
    drop_contains = ['Sold Price *', '* Sold Price'],
    max_depth=2
)

#Print columns
feature_matrix.columns
# Out:
# Index(['Sold Price', 'Sq Foot', 'Lot Size', 'Bedrooms',
#        'Elementary School Ratings', 'Junior High School Ratings',
#        'Sex Offender Count', 'Walk Score', 'Transit Score',
#        'Downtown Distance (Meters)', 'Avg Monthly Mortgage Rate (30Y)',
#        'Avg Monthly Mortgage Rate (30Y) * Bedrooms',
#        'Avg Monthly Mortgage Rate (30Y) * Downtown Distance (Meters)',
#        'Avg Monthly Mortgage Rate (30Y) * Elementary School Ratings',
#        'Avg Monthly Mortgage Rate (30Y) * Junior High School Ratings',
#        'Avg Monthly Mortgage Rate (30Y) * Lot Size',
#        'Avg Monthly Mortgage Rate (30Y) * Sex Offender Count',
#        'Avg Monthly Mortgage Rate (30Y) * Sq Foot',
#        'Avg Monthly Mortgage Rate (30Y) * Transit Score',
#        'Avg Monthly Mortgage Rate (30Y) * Walk Score',
#        'Bedrooms * Downtown Distance (Meters)',
#        'Bedrooms * Elementary School Ratings',
#        'Bedrooms * Junior High School Ratings', 'Bedrooms * Lot Size',
#        'Bedrooms * Sex Offender Count', 'Bedrooms * Sq Foot',
#        'Bedrooms * Transit Score', 'Bedrooms * Walk Score',
#        'Downtown Distance (Meters) * Elementary School Ratings',
#        'Downtown Distance (Meters) * Junior High School Ratings',
#        'Downtown Distance (Meters) * Lot Size',
#        'Downtown Distance (Meters) * Sex Offender Count',
#        'Downtown Distance (Meters) * Sq Foot',
#        'Downtown Distance (Meters) * Transit Score',
#        'Downtown Distance (Meters) * Walk Score',
#        'Elementary School Ratings * Junior High School Ratings',
#        'Elementary School Ratings * Lot Size',
#        'Elementary School Ratings * Sex Offender Count',
#        'Elementary School Ratings * Sq Foot',
#        'Elementary School Ratings * Transit Score',
#        'Elementary School Ratings * Walk Score',
#        'Junior High School Ratings * Lot Size',
#        'Junior High School Ratings * Sex Offender Count',
#        'Junior High School Ratings * Sq Foot',
#        'Junior High School Ratings * Transit Score',
#        'Junior High School Ratings * Walk Score',
#        'Lot Size * Sex Offender Count', 'Lot Size * Sq Foot',
#        'Lot Size * Transit Score', 'Lot Size * Walk Score',
#        'Sex Offender Count * Sq Foot', 'Sex Offender Count * Transit Score',
#        'Sex Offender Count * Walk Score', 'Sq Foot * Transit Score',
#        'Sq Foot * Walk Score', 'Transit Score * Walk Score'],
#       dtype='object')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">6b. Identify low-VIF (Less than 5) interaction terms using a stepwise approach.</div>

# %% [markdown]
# <div style="font-size: medium; color: green"><span style="font-weight: bold">Observations:</span> The only interaction terms with low VIF are 'Lot Size x Walk Score' and 'Sex Offender Count x Walk Score'.</div>

# %%
#Vars
#Drop outcome variable ('Sold Price') 
X = feature_matrix[[
    #Main terms
    'Sq Foot',
    'Lot Size',
    'Bedrooms',
    'Elementary School Ratings',
    'Junior High School Ratings',
    'Sex Offender Count',
    'Walk Score',
    'Transit Score',
    'Downtown Distance (Meters)',
    'Avg Monthly Mortgage Rate (30Y)',

    #Interaction terms
    #'Avg Monthly Mortgage Rate (30Y) * Bedrooms',
    #'Avg Monthly Mortgage Rate (30Y) * Downtown Distance (Meters)',
    #'Avg Monthly Mortgage Rate (30Y) * Elementary School Ratings',
    #'Avg Monthly Mortgage Rate (30Y) * Junior High School Ratings',
    #'Avg Monthly Mortgage Rate (30Y) * Lot Size',
    #'Avg Monthly Mortgage Rate (30Y) * Sex Offender Count',
    #'Avg Monthly Mortgage Rate (30Y) * Sq Foot',
    #'Avg Monthly Mortgage Rate (30Y) * Transit Score',
    #'Avg Monthly Mortgage Rate (30Y) * Walk Score',
    #'Bedrooms * Downtown Distance (Meters)',
    #'Bedrooms * Elementary School Ratings',
    #'Bedrooms * Junior High School Ratings',
    #'Bedrooms * Lot Size',
    #'Bedrooms * Sex Offender Count',
    #'Bedrooms * Sq Foot',
    #'Bedrooms * Transit Score',
    #'Bedrooms * Walk Score',
    #'Downtown Distance (Meters) * Elementary School Ratings',
    #'Downtown Distance (Meters) * Junior High School Ratings',
    #'Downtown Distance (Meters) * Lot Size',
    #'Downtown Distance (Meters) * Sex Offender Count',
    #'Downtown Distance (Meters) * Sq Foot',
    #'Downtown Distance (Meters) * Transit Score',
    ##'Downtown Distance (Meters) * Walk Score',
    #'Elementary School Ratings * Junior High School Ratings',
    #'Elementary School Ratings * Lot Size',
    #'Elementary School Ratings * Sex Offender Count',
    #'Elementary School Ratings * Sq Foot',
    #'Elementary School Ratings * Transit Score',
    #'Elementary School Ratings * Walk Score',
    #'Junior High School Ratings * Lot Size',
    #'Junior High School Ratings * Sex Offender Count',
    #'Junior High School Ratings * Sq Foot',
    ##'Junior High School Ratings * Transit Score',
    ##'Junior High School Ratings * Walk Score',
    #'Lot Size * Sex Offender Count',
    #'Lot Size * Sq Foot',
    #'Lot Size * Transit Score',
    'Lot Size * Walk Score',
    #'Sex Offender Count * Sq Foot',
    #'Sex Offender Count * Transit Score',
    'Sex Offender Count * Walk Score',
    #'Sq Foot * Transit Score',
    #'Sq Foot * Walk Score',
    ##'Transit Score * Walk Score'
]]

#Add intercept for VIF calculation
X.insert(0, 'Intercept', 1)

#Compute VIF for the independent variables
vif = pd.DataFrame({
    'Feature': X.columns,
    'VIF': [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
})

#Print VIF values
#A high VIF (>5) indicates multicollinearity
vif.sort_values(by='VIF', ascending=False)
# Out:
#                             Feature   VIF
# 0                         Intercept 78.07
# 12  Sex Offender Count * Walk Score  5.00
# 7                        Walk Score  4.29
# 6                Sex Offender Count  3.04
# 1                           Sq Foot  1.66
# 8                     Transit Score  1.56
# 11            Lot Size * Walk Score  1.54
# 3                          Bedrooms  1.37
# 9        Downtown Distance (Meters)  1.27
# 4         Elementary School Ratings  1.13
# 5        Junior High School Ratings  1.13
# 2                          Lot Size  1.07
# 10  Avg Monthly Mortgage Rate (30Y)  1.01

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">6c. Generate a correlation matrix for the chosen interaction terms.</div>

# %% [markdown]
# <div style="font-size: medium; color: green"><span style="font-weight: bold">Observations:</span> The only interaction term with a correlation greater than 0.10 to the outcome variable is 'Sex Offender Count x Walk Score'.</div>

# %%
#Print
feature_matrix[[
    'Sold Price',
    'Sex Offender Count * Walk Score',
    'Lot Size * Walk Score'
]].corr(method = 'pearson')
# Out:
#                                  Sold Price  Sex Offender Count * Walk Score  \
# Sold Price                             1.00                            -0.28
# Sex Offender Count * Walk Score       -0.28                             1.00
# Lot Size * Walk Score                  0.09                             0.32
#
#                                  Lot Size * Walk Score
# Sold Price                                        0.09
# Sex Offender Count * Walk Score                   0.32
# Lot Size * Walk Score                             1.00

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">6d. Incorporate interaction terms into the main dataset.</div>

# %%
housing_filtered_df['Sex Offender Count * Walk Score'] =  (housing_filtered_df['Sex Offender Count'] * housing_filtered_df['Walk Score']).astype('float')

#Print
housing_filtered_df[[
    'Sex Offender Count',
    'Walk Score',
    'Sex Offender Count * Walk Score'
]].head()
# Out:
#            Sex Offender Count  Walk Score  Sex Offender Count * Walk Score
# ML Number
# 202310874               59.00        8.00                           472.00
# 202310704              139.00        8.00                          1112.00
# 202310767               34.00       13.00                           442.00
# 202310769              139.00       36.00                          5004.00
# 202310294               43.00        2.00                            86.00

# %% [markdown]
# <div style="font-weight: bold; font-size: x-large; color: blue">***7. Save Dataset***</div>

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">7a. Save the filtered dataset.</div>

# %%
#Split the dataset into training and test sets
train, test = train_test_split(housing_filtered_df, test_size = 0.15, random_state = 1)

#Print
print(housing_filtered_df.shape)
print(train.shape)
print(test.shape)
# Out:
# (5637, 17)
# (4791, 17)
# (846, 17)

# %%
#Filtered (For predictive modeling)
train.to_feather("Datasets/V2/Prediction/Merged V2 - 85% (Original - For training models).feather")
test.to_feather("Datasets/V2/Prediction/Merged V2 - 15% (Original - For testing models).feather")

#Save sample
housing_filtered_df.head(200).to_csv("Temp/Merged_Sample_V2 (For prediction).csv")

# %% [markdown]
# <div style="font-weight: bold; font-size: x-large; color: blue">***8. Univariate Graphs (For the Presentation)***</div>

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">8a. Histogram for 'Lot Size'.</div>

# %%
createHist(housing_filtered_df, 'Lot Size')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">8b. Histogram for 'Downtown Distance (Meters)'.</div>

# %%
createHist(housing_filtered_df, 'Downtown Distance (Meters)')

# %% [markdown]
# <div style="font-weight: bold; font-size: x-large; color: blue">***9. Bivariate Graphs (For the Presentation)***</div>

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9a. Scatter Plot for 'Sold Price' & 'Sq Foot'.</div>

# %%
createScatterPlot(housing_filtered_df, 'Sq Foot', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9b. Scatter Plot for 'Sold Price' & 'Lot Size'.</div>

# %%
createScatterPlot(housing_filtered_df, 'Lot Size', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9c. Scatter Plot for 'Sold Price' & 'Bedrooms'.</div>

# %%
createScatterPlot(housing_filtered_df, 'Bedrooms', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9d. Scatter Plot for 'Sold Price' & 'Elementary School Ratings'.</div>

# %%
createScatterPlot(housing_filtered_df, 'Elementary School Ratings', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9e. Scatter Plot for 'Sold Price' & 'Junior High School Ratings'.</div>

# %%
createScatterPlot(housing_filtered_df, 'Junior High School Ratings', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9f. Scatter Plot for 'Sold Price' & 'Sex Offender Count'.</div>

# %%
createScatterPlot(housing_filtered_df, 'Sex Offender Count', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9g. Scatter Plot for 'Sold Price' & 'Walk Score'.</div>

# %%
createScatterPlot(housing_filtered_df, 'Walk Score', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9h. Scatter Plot for 'Sold Price' & 'Transit Score'.</div>

# %%
createScatterPlot(housing_filtered_df, 'Transit Score', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9i. Scatter Plot for 'Sold Price' & 'Downtown Distance (Meters)'.</div>

# %%
createScatterPlot(housing_filtered_df, 'Downtown Distance (Meters)', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9j. Scatter Plot for 'Sold Price' & 'Avg Monthly Mortgage Rate (30Y)'.</div>

# %%
createScatterPlot(housing_filtered_df, 'Avg Monthly Mortgage Rate (30Y)', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9k. Box Plot for 'Sold Price' & 'Zipcode'.</div>

# %%
createBoxPlot(housing_filtered_df, 'Zipcode', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9l. Box Plot for 'Sold Price' & 'Pool_Inground'.</div>

# %%
createBoxPlot(housing_filtered_df, 'Pool_Inground', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9m. Box Plot for 'Sold Price' & 'Pool_Community'.</div>

# %%
createBoxPlot(housing_filtered_df, 'Pool_Community', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">9n. Box Plot for 'Sold Price' & 'Pool_Spa'.</div>

# %%
createBoxPlot(housing_filtered_df, 'Pool_Spa', 'Sold Price')

# %% [markdown]
# <div style="font-weight: bold; font-size: x-large; color: blue">***10. Multivariate Graphs (For the Presentation)***</div>

# %% [markdown]
# <div style="font-weight: bold; font-size: large; color: blue">10a. 3D Plot for 'Walk Score', 'Sex Offender Count', and 'Sold Price'.</div>

# %%
create3DScatterPlot(housing_filtered_df, 'Walk Score', 'Sex Offender Count', 'Sold Price')

# %%
housing_filtered_df[[
    'Zipcode',
    'Sex Offender Count'
]].head(5)
# Out:
#           Zipcode  Sex Offender Count
# ML Number
# 202310874   93313               59.00
# 202310704   93308              139.00
# 202310767   93312               34.00
# 202310769   93308              139.00
# 202310294   93311               43.00
